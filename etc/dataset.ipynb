# %%
# kaggle car dataset
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dhiadah/car-data-train")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 12.7G/12.7G [02:25<00:00, 93.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/dhiadah/car-data-train/versions/1

# %%
# AI hub 자동차 차종/연식/번호판 인식용 영상
# import gdown, zipfile, os

# file_id = '1cphOiHucE759f_xorWulMESer1ONjW_l'

# gdown.download(f'https://drive.google.com/uc?id={file_id}', 'file.zip', quiet=False) # (다운로드받을것, 다운로드파일이름지정, 로그확인)

# dir = 'cat-and-dog'
# os.makedirs(dir, exist_ok=True) # exist_ok -> 없으면 만들고 있어도 에러 발생 없이 넘어감

# with zipfile.ZipFile('file.zip', 'r') as z:
#   z.extractall(dir)

import gdown, zipfile, os

file_id = '170eZ_8frqfJg2rTS0CdNCSMt7-GskdsC'

gdown.download(f'https://drive.google.com/uc?id={file_id}', 'file.zip', quiet=False) # (다운로드받을것, 다운로드파일이름지정, 로그확인)

dir = 'car'
os.makedirs(dir, exist_ok=True) # exist_ok -> 없으면 만들고 있어도 에러 발생 없이 넘어감


def extract_file(file_path, extract_to):
    """압축 파일 해제 함수"""
    if file_path.endswith('.zip'):
        with zipfile.ZipFile(file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_to)
            print(f"Extracted: {file_path} to {extract_to}")
    else:
        print(f"Skipped (unsupported format): {file_path}")

def extract_all_in_folder(folder_path):
    """폴더 내 모든 압축 파일 해제"""
    for root, _, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            extract_to = root  # 압축 해제 폴더는 현재 파일이 위치한 폴더
            extract_file(file_path, extract_to)


os.makedirs(dir, exist_ok=True)

# 3. 폴더 내 모든 압축 파일 해제
extract_all_in_folder(dir)
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/download.py:33: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = bs4.BeautifulSoup(line, features="html.parser")
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/gdown/download.py in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     266         try:
# --> 267             url = get_url_from_gdrive_confirmation(res.text)
#     268         except FileURLRetrievalError as e:
#
# /usr/local/lib/python3.10/dist-packages/gdown/download.py in get_url_from_gdrive_confirmation(contents)
#      54     if not url:
# ---> 55         raise FileURLRetrievalError(
# ...
